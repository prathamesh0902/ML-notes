# %% [markdown]
# # Lasso and Ridge

# %% [markdown]
# - [Ridge vs Lasso](https://chatgpt.com/s/t_69fc6d2309088191a50f635dc7c3294c)
# - [Youtube](https://www.youtube.com/shorts/E0YeXQkkcVE)
# - [Lasso Regression](https://www.youtube.com/shorts/fjXS-R_Vmmk), [Ridge Regression](https://www.youtube.com/watch?v=wB-A8e1Vh6I)
# - [How coefficients become 0 in Lasso but not in Ridge](https://chatgpt.com/s/t_69fc6edd6dc881919c8477db657584ca)
