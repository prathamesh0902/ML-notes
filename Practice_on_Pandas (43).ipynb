# %%
# pip install pandas
import pandas as pd

# %%
# Series
# DataFrame
df = [11,22,33,44,55,66]
df

# %%
df = pd.Series([11,22,33,44,55,66])
df

# %%
df = pd.Series([11,22,33,44,55,66],index=[1,2,3,4,5,6],dtype=float,name ='Myinfo')
df

# %%
type(df)

# %%
df

# %%
df[1]

# %%
df[:3]

# %%
df[1] = 99

# %%
df

# %%
df[df<50]

# %%
df[df>50]

# %%
df[(df>20) & (df<40)]

# %%
df

# %%
df[7] = 78

# %%
df

# %%
df.drop(labels=5,inplace=True)

# %%
df

# %%
df.reset_index(drop=True,inplace=True)

# %%
df

# %%
df[len(df)] = 89

# %%
df

# %%
df

# %%
df.sort_values(ascending=False,inplace=True)

# %%
df

# %%
df.reset_index(drop=True,inplace=True)

# %%
df

# %%
df[:2]

# %%
df[4]

# %%
n1 = pd.Series({1011:"Mohan",1012:'Kisan',1013:'Shyam',1014:'Raghav'})
n1

# %%
n1.reset_index(drop=True,inplace=True)

# %%
n1# DataFrame

# %%
n1= list(n1)

# %%
n1 = pd.Series(n1,index=range(1011,1015))
n1

# %%
list(range(1011,1015))

# %%
n1.reset_index( )

# %%
import pandas as pd

# %%
# DataFrame
emp_info = pd.DataFrame({'Emp_id':[1011,1012,1013,1014] , 'Emp_Name':['Mohan','Kisan','Raghav','Keshav']})
emp_info

# %%
emp_info["Desg"] = ['DA','DBA','S/W', 'AI']

# %%
emp_info

# %%
emp_info['Salary']=[25600,42000,52000,49000]

# %%
emp_info

# %%
emp_info[['Emp_id','Salary','Desg']]

# %%
emp_info.loc[0]

# %%
emp_info.loc[[1,3]]

# %%
emp_info

# %%
emp_info.loc[4] = [1015,'Raghu','DA',45000]

# %%
emp_info

# %%
emp_info.loc[1,'Desg'] = 'HR'

# %%
emp_info

# %%
emp_info[emp_info['Emp_id']==1013]

# %%
emp_info.loc[2,'Salary'] = emp_info.loc[2,'Salary'] + emp_info.loc[2,'Salary']*0.1

# %%
emp_info

# %%
emp_info[emp_info['Desg'] == 'DA']

# %%
emp_info.loc[0,'Salary'] = emp_info.loc[0,'Salary'] + emp_info.loc[0,'Salary']*0.05

# %%
emp_info.loc[4,'Salary'] = emp_info.loc[4,'Salary'] + emp_info.loc[4,'Salary']*0.05

# %%
emp_info

# %%
emp_info['Salary'].max()

# %%
emp_info['Salary'].min()

# %%
emp_info['Salary'].mean()

# %%
sum(emp_info['Salary'])

# %%
emp_info[emp_info['Salary']==emp_info['Salary'].max() ]

# %%
emp_info[emp_info['Salary']==emp_info['Salary'].min() ]

# %%
emp_info

# %%
emp_info.sort_values(by='Salary',ascending=False).head(2)

# %%
emp_info.sort_values(by='Salary',ascending=False).tail(2)

# %%
emp_info

# %%
emp_info.query("Desg == 'DA' and Salary > 30000  ")

# %%
emp_info.query("Salary > 30000  and Salary < 50000 and Desg=='DA' ")

# %%
emp_info

# %%
emp_info.drop('Emp_Name',axis=1,inplace=True)

# %%
emp_info

# %%
emp_info.drop(1,inplace=True)

# %%
emp_info

# %%
emp_info.to_excel("Emp_info.xlsx")

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/titaanic12.csv")

# %%
df

# %%
df.pivot(columns='PassengerId',index='Sex',values='Pclass')

# %%
df.head(20)

# %%
df.tail(10)

# %%
df.shape

# %%
df.columns

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
df.head()

# %%
df[df['Age']==df['Age'].max()]

# %%
df[df['Age']==df['Age'].min()]

# %%
df.query("Sex=='male' and Age > 40 and Embarked == 'Q' ")

# %%
df.head()

# %%
df.isnull().any()

# %%
df.isnull().sum()

# %%
df['Sex'].unique()

# %%
df['Sex'].value_counts()

# %%
round(df['Age'].mean(),1)

# %%
df['Age'].fillna(round(df['Age'].mean(),1),inplace=True)

# %%
df.isnull().sum()

# %%
df.shape

# %%
df['Cabin'].mode()[0]

# %%
df['Cabin'].fillna(df['Cabin'].mode()[0],inplace=True)

# %%
df.isnull().sum()

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()

# %%
df.head()

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()

# %%
df.head()

# %%
df.rename(columns={'Sex':'Gender'},inplace=True)

# %%
df.head()

# %%
df['Survived'].replace(to_replace=[1,0],value=['Alive','No More'],inplace=True)

# %%
df.head()

# %%
df.head()

# %%
df.groupby('Gender')['Age'].mean()

# %%
df.groupby(['Gender','Survived'])['Age'].mean()

# %%
df.groupby('Survived')['Age'].mean()

# %%
df.groupby(['Pclass','Gender'])['Age'].mean()

# %%
df.groupby(['Pclass','Gender'])['Age'].count()

# %%
df.groupby(['Pclass','Survived'])['Age'].count()

# %%
df.pivot_table(index='Pclass',columns='Gender',values='Age',aggfunc=['mean','max','min','count'])

# %%
df.head()

# %%
df.groupby('Pclass')['Fare'].sum()

# %%
df.groupby(['Pclass','Sex'])['Fare'].sum()
