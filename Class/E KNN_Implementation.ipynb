# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("iris")
df.head()

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()

# %%
df['species'].unique()

# %%
from sklearn.preprocessing import LabelEncoder
encod = LabelEncoder()
df['species'] = encod.fit_transform(df['species'])

# %%
df.head()

# %%
x= df.drop('species',axis=1)
y=df['species']

# %%
x.head()

# %%
y

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0,test_size=0.3)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors = 2, metric = 'euclidean')

# %%
model.fit(x_train,y_train)

# %%
model.score(x_train,y_train)

# %%
model.score(x_test,y_test)

# %%
df['species'].value_counts()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_estimator(model, x_train, y_train)

# %%
ConfusionMatrixDisplay.from_estimator(model, x_test, y_test)

# %%
yp_train = model.predict(x_train)
yp_test = model.predict(x_test)

# %%
pd.DataFrame({'Act':y_train,'Predicted':yp_train})

# %%
pd.DataFrame({'Act':y_test,'Predited':yp_test})

# %%
model.predict(np.array([7,1.0,6.5,0.8]).reshape(1,-1))

# %%
df.head()

# %%
df['species'].value_counts()

# %%
model.predict(np.array([7,1.0,6.5,0.8]).reshape(1,-1))
