# %% [markdown]
# ### Feature Selection- Dropping constant features
# In this step we will be removing the features which have constant features which are actually not important
# for solving the problem statement

# %%
import pandas as pd
from sklearn.feature_selection import VarianceThreshold

# %%
# Import pandas to create DataFrame
import pandas as pd

# Make DataFrame of the given data
data = pd.DataFrame({"A":[1,2,4,1,2,4],
                    "B":[4,5,6,7,8,9],
                    "C":[4,4,4,4,4,4],
                    "D":[1,1,1,1,1,1]})

# %%
data.head()

# %%
data.columns

# %% [markdown]
# ##### Variance Threshold
# Feature selector that removes all low-variance features.
#
# This feature selection algorithm looks only at the features (X), not the desired outputs (y), and can thus be used for unsupervised learning.

# %%
### It will zero variance features
from sklearn.feature_selection import VarianceThreshold

var = VarianceThreshold(threshold=0.5)

# %%
fd =  var.fit(data)

# %%
fd.get_support()

# %%
data.columns

# %%
data.columns[fd.get_support()]

# %%
# col = list(data.columns[var.get_support()])

# %%
# col

# %%
data.columns

# %%
n1 = [i for i in data.columns if i in data.columns[fd.get_support()]]

# %%
n1

# %%
data= data[col]

# %%
data

# %%
zero_ther = [i for i in data.columns if i not in data.columns[var.get_support()]]
zero_ther

# %%
data.drop(zero_ther, axis=1)

# %%
new_data = pd.DataFrame({'A':data['A'] ,'B':data['B']})

# %%
new_data

# %%
data.columns

# %%
constant_columns = [i for i in data.columns if i not in data.columns[var_thres.get_support()]]

print(constant_columns)

# %%
for feature in constant_columns:
     print(feature)

# %%
data.drop(constant_columns,axis=1)

# %% [markdown]
# #### Lets practise on bigger dataset
# https://www.kaggle.com/c/santander-customer-satisfaction/data?select=train.csv

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.feature_selection import VarianceThreshold

# %%
df=pd.read_csv('/content/train-2.csv',nrows=10000)

# %%
df.shape

# %%
df.head()

# %%
df.columns

# %%
df['TARGET'].value_counts()

# %%
X=df.drop(labels=['TARGET'], axis=1)
y=df['TARGET']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)

X_train.shape, X_test.shape

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)

# %%
model.score(X_train,y_train)

# %% [markdown]
# #### Lets apply the variance threshold

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
var_thres=VarianceThreshold(threshold=0.5)
var_thres.fit(X_train)

# %%
var_thres.get_support()

# %%
### Finding non constant features
sum(var_thres.get_support())

# %%
# Lets Find non-constant features
len(X_train.columns[var_thres.get_support()])

# %%
constant_columns = [column for column in X_train.columns
                    if column not in X_train.columns[var_thres.get_support()]]

print(len(constant_columns))

# %%
for column in constant_columns:
    print(column)

# %%
X_train = X_train.drop(constant_columns,axis=1)

# %%
X_train.shape

# %%
model.fit(X_train,y_train)

# %%
model.score(X_train,y_train)
